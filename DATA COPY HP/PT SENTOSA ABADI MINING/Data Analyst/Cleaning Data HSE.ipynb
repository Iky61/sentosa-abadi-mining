# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import requests
from datetime import datetime
import re
from collections import Counter
import math
from tqdm import tqdm

# setting pandas
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# setting seaborn
sns.set_palette('Spectral')
sns.set_context('notebook', font_scale=1)
sns.set_style('whitegrid')
sns.set(rc={"axes.facecolor":"#FFF9ED","figure.facecolor":"#FFF9ED"})

warnings.filterwarnings('ignore')

# %%
path = '/Users/dickyaryanto/Documents/PT Sentosa Abadi Mining/Data Analyst/data kotor HSE/'
files = os.listdir(path)
try:
    files.remove('~$Data Accident 2024.xlsx')
    files.remove('~$Data Accident 2023.xlsx')
    files.remove('.DS_Store')
except:
    None
_ = []
for i in files:
    data = pd.read_excel(path + i, sheet_name='Sheet1')
    _.append(data)
hse = pd.concat(_)

# %%
hse[['Waktu Kejadian','Kategori','Tempat Kejadian','No Unit','Divisi','Korban/Pelaku']]
# Out:
#          Waktu Kejadian         Kategori         Tempat Kejadian  No Unit  \
# 0   2024-01-04 17:00:00  Property Damage         Workshop SA-APP    LV-10
# 1   2024-01-04 14:47:00         Nearmiss                    KM 4   DT-161
# 2   2024-01-07 11:42:00  Property Damage                    KM 2   DT-268
# 3   2024-01-08 10:37:00         Nearmiss                   KM 25   DT-347
# 4   2024-01-17 08:08:00  Property Damage        Area Pabrik IMIP   DT-398
# ..                  ...              ...                     ...      ...
# 57  2023-11-17 00:00:00  Property Damage           Stockpile QMB  APP 363
# 58  2023-11-18 00:00:00  Property Damage    Jalan utama PT. IMIP  APP 501
# 59  2023-12-02 00:00:00  Property Damage             Gudang HYNC    SA262
# 60  2023-12-06 00:00:00  Property Damage        area workshop SA    SA213
# 61  2023-12-07 00:00:00  Property Damage  Jln. Houling BDM KM 14    SA265
#
#                       Divisi      Korban/Pelaku
# ...
